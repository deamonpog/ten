# %%
import pandas as pd
import gzip
import json
import glob

# %%
dir = 'C:\\STUFF\\RESEARCH\\TwitterLookup\\tlfr\\Cache\\'

# %%
filestyle = 'querylist_cache_*_*.json.gzip'

# %%
files = glob.glob(dir + filestyle)
len(files)
# Out:
# 20842

# %%
def ReadFromGzipJSON(in_file_path):
    with gzip.open(in_file_path, 'r') as fin:
        json_bytes = fin.read()
    json_str = json_bytes.decode('utf-8')
    data = json.loads(json_str)
    return data

# %%
d = ReadFromGzipJSON(files[0])
d
# Out:
# {'data': [{'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'text': '@Peroporqu_ :)',
#    'author_id': '1385729645740449804',
#    'in_reply_to_user_id': '1500536286591033351',
#    'edit_history_tweet_ids': ['1509757106202849291'],
#    'conversation_id': '1500971180395802633',
#    'id': '1509757106202849291',
#    'entities': {'mentions': [{'start': 0,
#       'end': 11,
#       'username': 'Peroporqu_',
#       'id': '1500536286591033351'}]},
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1500971180395802633'}],
#    'created_at': '2022-04-01T04:58:38.000Z'},
#   {'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'text': 'RT @purpleluvrain: @jlints58 love it dear sweet man, love the imagery of this.. it click clicks in my head &lt;33',
#    'author_id': '4501930040',
# ...

# %%
d
# Out:
# {'data': [{'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'text': '@Peroporqu_ :)',
#    'author_id': '1385729645740449804',
#    'in_reply_to_user_id': '1500536286591033351',
#    'edit_history_tweet_ids': ['1509757106202849291'],
#    'conversation_id': '1500971180395802633',
#    'id': '1509757106202849291',
#    'entities': {'mentions': [{'start': 0,
#       'end': 11,
#       'username': 'Peroporqu_',
#       'id': '1500536286591033351'}]},
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1500971180395802633'}],
#    'created_at': '2022-04-01T04:58:38.000Z'},
#   {'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0,
#     'impression_count': 0},
#    'text': 'RT @purpleluvrain: @jlints58 love it dear sweet man, love the imagery of this.. it click clicks in my head &lt;33',
#    'author_id': '4501930040',
# ...
